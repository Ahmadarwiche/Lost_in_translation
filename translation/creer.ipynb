# %%
import requests
import pandas as pd

# %%
# Utilisation de pd.set_option pour afficher toutes les colonnes du DataFrame
pd.set_option('display.max_columns', None)

station_names = ["Paris Bercy", "Paris Saint-Lazare", "Paris Gare de Lyon", "Paris Gare du Nord", "Paris Montparnasse", "Paris Est", "Paris Austerlitz"]

records = []

for name in station_names:
    for year in range(2019, 2023):
        url = f"https://ressources.data.sncf.com/api/records/1.0/search/?dataset=objets-trouves-restitution&q=Paris&rows=10000&sort=date&facet=date&facet=gc_obo_gare_origine_r_name&facet=gc_obo_type_c&refine.gc_obo_gare_origine_r_name={name.replace(' ', '+')}&refine.date={year}"
        response = requests.get(url)
        data = response.json()
        records += data['records']

df1 = pd.json_normalize(records)
df1 = df1.loc[:, ['fields.date', 'fields.gc_obo_gare_origine_r_name', 'fields.gc_obo_type_c']]
df1['fields.date'] = pd.to_datetime(df1['fields.date']).dt.strftime('%Y-%m-%d')
# création du CSV 
# df1.to_csv("objets-trouves.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 13
#      11         response = requests.get(url)
#      12         data = response.json()
# ---> 13         records += data['records']
#      15 df1 = pd.json_normalize(records)
#      16 df1 = df1.loc[:, ['fields.date', 'fields.gc_obo_gare_origine_r_name', 'fields.gc_obo_type_c']]
#
# KeyError: 'records'

# %%
df1
# Out:
#       fields.date fields.gc_obo_gare_origine_r_name  \
# 0      2019-12-29                       Paris Bercy
# 1      2019-12-26                       Paris Bercy
# 2      2019-12-26                       Paris Bercy
# 3      2019-12-26                       Paris Bercy
# 4      2019-12-26                       Paris Bercy
# ...           ...                               ...
# 81627  2022-01-04                  Paris Austerlitz
# 81628  2022-01-04                  Paris Austerlitz
# 81629  2022-01-04                  Paris Austerlitz
# 81630  2022-01-04                  Paris Austerlitz
# 81631  2022-01-04                  Paris Austerlitz
#
#                                     fields.gc_obo_type_c
# 0           Porte-monnaie / portefeuille, argent, titres
# 1                    Bagagerie: sacs, valises, cartables
# 2                    Bagagerie: sacs, valises, cartables
# 3                    Bagagerie: sacs, valises, cartables
# ...

# %%
import sqlite3
connexion= sqlite3.connect("bdd.db")
curseur = connexion.cursor()
curseur.execute('''CREATE TABLE IF NOT EXISTS df1 (
              date TEXT NOT NULL,
              gare TEXT NOT NULL,
              feels_like FLOAT,
              type_objet TEXT
              );''')

connexion.commit()

query = "INSERT INTO df1 (date, gare, type_objet) VALUES (?, ?, ?)"
curseur.executemany(query, df1.values.tolist())

# Validation de la transaction
connexion.commit()

# Fermeture de la connexion
connexion.close()

# %% [markdown]
# **DATA FRAME objet perdu 2019**

# %%
df1['fields.date'] = pd.to_datetime(df1['fields.date'])
df1_2019 = df1[df1['fields.date'].dt.year == 2019]
df1_2019
# Out:
#       fields.date fields.gc_obo_gare_origine_r_name  \
# 0      2019-12-29                       Paris Bercy
# 1      2019-12-26                       Paris Bercy
# 2      2019-12-26                       Paris Bercy
# 3      2019-12-26                       Paris Bercy
# 4      2019-12-26                       Paris Bercy
# ...           ...                               ...
# 80380  2019-01-03                  Paris Austerlitz
# 80381  2019-01-03                  Paris Austerlitz
# 80382  2019-01-03                  Paris Austerlitz
# 80383  2019-01-03                  Paris Austerlitz
# 80384  2019-01-02                  Paris Austerlitz
#
#                                     fields.gc_obo_type_c
# 0           Porte-monnaie / portefeuille, argent, titres
# 1                    Bagagerie: sacs, valises, cartables
# 2                    Bagagerie: sacs, valises, cartables
# 3                    Bagagerie: sacs, valises, cartables
# ...

# %%
#df_provisoire_2019['fields.date'] = pd.to_datetime(df_provisoire_['fields.date'])
df1_2019['fields.date']=df1_2019['fields.date'].dt.strftime('%U')
# Out:
# /tmp/ipykernel_330594/2308099575.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2019['fields.date']=df1_2019['fields.date'].dt.strftime('%U')

# %%
df1_2019
# Out:
#       fields.date fields.gc_obo_gare_origine_r_name  \
# 0              52                       Paris Bercy
# 1              51                       Paris Bercy
# 2              51                       Paris Bercy
# 3              51                       Paris Bercy
# 4              51                       Paris Bercy
# ...           ...                               ...
# 80380          00                  Paris Austerlitz
# 80381          00                  Paris Austerlitz
# 80382          00                  Paris Austerlitz
# 80383          00                  Paris Austerlitz
# 80384          00                  Paris Austerlitz
#
#                                     fields.gc_obo_type_c
# 0           Porte-monnaie / portefeuille, argent, titres
# 1                    Bagagerie: sacs, valises, cartables
# 2                    Bagagerie: sacs, valises, cartables
# 3                    Bagagerie: sacs, valises, cartables
# ...

# %%
#df1_2019.to_csv("objets-trouves_2019.csv", index=False)

# %%
df1_2019['fields.date'].value_counts().sort_index()
# Out:
# 00    364
# 01    456
# 02    450
# 03    511
# 04    449
# 05    532
# 06    576
# 07    483
# 08    560
# 09    537
# 10    436
# 11    567
# 12    551
# 13    519
# 14    472
# 15    567
# 16    535
# 17    482
# 18    526
# 19    526
# 20    524
# 21    496
# 22    584
# 23    554
# 24    563
# 25    579
# 26    627
# 27    597
# 28    677
# 29    541
# 30    450
# 31    540
# 32    562
# 33    552
# 34    612
# 35    593
# 36    481
# 37    645
# 38    479
# 39    422
# 40    576
# 41    459
# 42    547
# 43    504
# 44    594
# 45    448
# 46    509
# 47    504
# 48    371
# 49    188
# 50    283
# 51    259
# 52    142
# Name: fields.date, dtype: int64

# %% [markdown]
# **DATA FRAME objet perdu  2020**

# %%
df1['fields.date'] = pd.to_datetime(df1['fields.date'])
df1_2020 = df1[df1['fields.date'].dt.year == 2020]
df1_2020['fields.date']=df1_2020['fields.date'].dt.strftime('%U')
# Out:
# /tmp/ipykernel_330594/2798880336.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2020['fields.date']=df1_2020['fields.date'].dt.strftime('%U')

# %%
df1_2020
# Out:
#       fields.date fields.gc_obo_gare_origine_r_name  \
# 570            52                       Paris Bercy
# 571            52                       Paris Bercy
# 572            52                       Paris Bercy
# 573            52                       Paris Bercy
# 574            51                       Paris Bercy
# ...           ...                               ...
# 80619          01                  Paris Austerlitz
# 80620          01                  Paris Austerlitz
# 80621          00                  Paris Austerlitz
# 80622          00                  Paris Austerlitz
# 80623          00                  Paris Austerlitz
#
#                            fields.gc_obo_type_c
# 570         Bagagerie: sacs, valises, cartables
# 571    Pièces d'identités et papiers personnels
# 572         Bagagerie: sacs, valises, cartables
# 573                                     Optique
# 574         Bagagerie: sacs, valises, cartables
# ...

# %%
#df1_2020.to_csv("objets-trouves_2020.csv", index=False)

# %% [markdown]
# **DATA FRAME objet perdu 2021**

# %%
df1['fields.date'] = pd.to_datetime(df1['fields.date'])
df1_2021 = df1[df1['fields.date'].dt.year == 2021]
df1_2021['fields.date']=df1_2021['fields.date'].dt.strftime('%U')
# Out:
# /tmp/ipykernel_330594/764819555.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2021['fields.date']=df1_2021['fields.date'].dt.strftime('%U')

# %%
#df1_2021.to_csv("objets-trouves_2021.csv", index=False)

# %% [markdown]
# **DATA FRAME objet perdu 2022**

# %%
df1['fields.date'] = pd.to_datetime(df1['fields.date'])
df1_2022 = df1[df1['fields.date'].dt.year == 2022]
df1_2022['fields.date']=df1_2022['fields.date'].dt.strftime('%U')
# Out:
# /tmp/ipykernel_330594/3772376561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_2022['fields.date']=df1_2022['fields.date'].dt.strftime('%U')

# %%
#df1_2022.to_csv("objets-trouves_2022.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df1_2022.to_csv("objets-trouves_2022.csv", index=False)
#
# NameError: name 'df1_2022' is not defined

# %% [markdown]
# **DATA FRAME objet perdu par jour**

# %%
df1_jour = df1.groupby(pd.Grouper(key='fields.date', freq='D')).count()
df1_jour = df1_jour.reset_index()
df1_jour['objet_jour'] = df1_jour['fields.gc_obo_type_c']
df1_jour[['fields.date', 'objet_jour']].to_csv('objet-perdu-jour.csv')

# %% [markdown]
# **DATA FRAME TEMPERATURE**

# %%
df_temperature = pd.read_csv("temperature.csv")
# Prendre le DataFrame jusqu à la ligne 35064
df_temperature = df_temperature[:35064]

# # Sauvegarder le fichier CSV
# df_temperature.to_csv('temperature.csv', index=False)
# df_temperature = pd.read_csv("temperature.csv")

df_temperature = df_temperature[['time', 'temperature_2m (°C)']]
df_temperature
# Out:
#                    time  temperature_2m (°C)
# 0      2019-01-01T00:00                  7.4
# 1      2019-01-01T01:00                  7.2
# 2      2019-01-01T02:00                  7.1
# 3      2019-01-01T03:00                  6.9
# 4      2019-01-01T04:00                  6.7
# ...                 ...                  ...
# 35059  2022-12-31T19:00                 14.3
# 35060  2022-12-31T20:00                 14.9
# 35061  2022-12-31T21:00                 15.2
# 35062  2022-12-31T22:00                 15.1
# 35063  2022-12-31T23:00                 14.9
#
# [35064 rows x 2 columns]

# %%
# Convertir la colonne "time" en type de données datetime
df_temperature['time'] = pd.to_datetime(df_temperature['time'])

# Regrouper les données par jour : freq = 'D'
df_temperature_jour = df_temperature.groupby(pd.Grouper(key='time', freq='D')).mean(numeric_only=True)

# # # Afficher les moyennes des températures par jour
df_temperature_jour
# Out:
#             temperature_2m (°C)
# time
# 2019-01-01             7.558333
# 2019-01-02             5.420833
# 2019-01-03             2.325000
# 2019-01-04             1.500000
# 2019-01-05             2.875000
# ...                         ...
# 2022-12-27             5.654167
# 2022-12-28            10.150000
# 2022-12-29             9.591667
# 2022-12-30             9.904167
# 2022-12-31            15.100000
#
# [1461 rows x 1 columns]

# %%
df_temperature_jour =  df_temperature_jour.reset_index()

# %%
df_temperature_jour
# Out:
#            time  temperature_2m (°C)
# 0    2019-01-01             7.558333
# 1    2019-01-02             5.420833
# 2    2019-01-03             2.325000
# 3    2019-01-04             1.500000
# 4    2019-01-05             2.875000
# ...         ...                  ...
# 1456 2022-12-27             5.654167
# 1457 2022-12-28            10.150000
# 1458 2022-12-29             9.591667
# 1459 2022-12-30             9.904167
# 1460 2022-12-31            15.100000
#
# [1461 rows x 2 columns]

# %%
# mettre à jour / index = True
#df_temperature_jour.to_csv('temperature_jour.csv')

# %% [markdown]
# **DATA FRAME FREQUENTATION**

# %%
df_frequentation = pd.read_csv('frequentation-gares.csv', sep =';')

# %%
df_frequentation
# Out:
#                           Nom de la gare  Code UIC  Code postal  \
# 0  Paris Bercy Bourgogne_Pays d'Auvergne  87686667        75012
# 1                     Paris Gare de Lyon  87686006        75012
# 2                     Paris Montparnasse  87391003        75015
# 3                     Paris Gare du Nord  87758904        75010
# 4                  Cormeilles-en-Parisis  87381863        95240
# 5                       Paris Austerlitz  87547000        75013
# 6                              Paris Est  87113001        75010
# 7                     Paris Saint-Lazare  87384008        75008
#
#   Segmentation DRG  Total Voyageurs 2021  \
# 0                a               3347763
# 1                a              79986275
# 2                a              41043477
# 3                a             126622180
# 4                b               3317416
# 5                a              22281301
# 6                a              27758686
# 7                a              91502192
#
# ...

# %%
# retirer les colonnes inutiles
df_frequentation = df_frequentation[['Nom de la gare', 'Total Voyageurs + Non voyageurs 2019', 'Total Voyageurs + Non voyageurs 2020', 'Total Voyageurs + Non voyageurs 2021']]

# renommer les colonnes
df_frequentation = df_frequentation.rename(columns={'Nom de la gare': 'gare', 'Total Voyageurs + Non voyageurs 2019': 'frequentation_2019', 'Total Voyageurs + Non voyageurs 2020': 'frequentation_2020', 'Total Voyageurs + Non voyageurs 2021': 'frequentation_2021'})

# retirer les lignes inutiles
df_frequentation = df_frequentation[df_frequentation['gare'] != "Cormeilles-en-Parisis"]

# %%
# renommer le nom d une gare
df_frequentation.loc[df_frequentation['gare'] == "Paris Bercy Bourgogne_Pays d'Auvergne", 'gare'] = "Paris Bercy"

# %%
# Définition des coordonnées de longitude et latitude pour chaque gare

longitude = [2.3768, 2.3731, 2.3216, 2.3551, 2.3642, 2.3585, 2.3270]
latitude = [48.8395, 48.8448, 48.8383, 48.8809, 48.8408, 48.8760, 48.8759]

# Ajout des colonnes de longitude et latitude dans le dataframe
df_frequentation = df_frequentation.assign(longitude=longitude, latitude=latitude)

# %%
#analyse
df_frequentation.index
# Out:
# Index(['Paris Bercy', 'Paris Gare de Lyon', 'Paris Montparnasse',
#        'Paris Gare du Nord', 'Paris Austerlitz', 'Paris Est',
#        'Paris Saint-Lazare'],
#       dtype='object', name='gare')

# %%
df_frequentation.set_index('gare', inplace=True)

# %%
#analyse
df_frequentation.loc['Paris Est'][['latitude','longitude']].to_list()
# Out:
# [2.359021, 48.876985]

# %%
#analyse
for city in df_frequentation.index:
    print(df_frequentation.loc[city][['longitude','latitude']].to_list())
# Out:
# [2.381581, 48.837634]
# [2.373056, 48.844867]
# [2.321958, 48.840085]
# [2.359903, 48.880931]
# [2.364896, 48.840199]
# [2.359021, 48.876985]
# [2.326532, 48.875414]

# %%
df_frequentation
# Out:
#                     frequentation_2019  frequentation_2020  \
# gare
# Paris Bercy                    4482042             2592964
# Paris Gare de Lyon           140121852            67873723
# Paris Montparnasse            76622754            40615322
# Paris Gare du Nord           272898471           107666015
# Paris Austerlitz              22423095            13602554
# Paris Est                     52060520            27242868
# Paris Saint-Lazare           143120561           152624513
#
#                     frequentation_2021  longitude   latitude
# gare
# Paris Bercy                    3474572   2.381581  48.837634
# Paris Gare de Lyon           100871407   2.373056  48.844867
# Paris Montparnasse            51406616   2.321958  48.840085
# Paris Gare du Nord           148849186   2.359903  48.880931
# Paris Austerlitz              22814864   2.364896  48.840199
# Paris Est                     35041906   2.359021  48.876985
# ...

# %%
#analyse
df_frequentation.shape[0]
# Out:
# 7

# %%
#df_frequentation.to_csv('frequentation-gares-netoyé.csv')

# %% [markdown]
# **MEDIANE JOURNALIERE/SAISON**

# %%
# renommer les colonnes
df1 = df1.rename(columns={'fields.date': 'date', 'fields.gc_obo_gare_origine_r_name': 'gare', 'fields.gc_obo_type_c': 'type_objet'})

# retirer les colonnes inutiles
df1 = df1.drop('type_objet', axis=1)

# Conversion de la colonne 'fields.date' en type 'datetime'
df1['date'] = pd.to_datetime(df1['date'])

# Filtrage des données entre les deux dates spécifiées sans modifier le DataFrame d'origine
dico_saison = {
    'hiver 2019'     : ['2019-01-01', '2019-02-28', 'df_hiver_19'],
    'printemps 2019' : ['2019-03-01', '2019-05-31', 'df_printemps_19'],
    'été 2019'       : ['2019-06-01', '2019-08-31', 'df_été_19'],
    'automne 2019'   : ['2019-09-01', '2019-11-30', 'df_automne_19'],
    'hiver 2020'     : ['2019-12-01', '2020-02-29', 'df_hiver_20'],
    'printemps 2020' : ['2020-03-01', '2020-05-31', 'df_printemps_20'],
    'été 2020'       : ['2020-06-01', '2020-08-31', 'df_été_20'],
    'automne 2020'   : ['2020-09-01', '2020-11-30', 'df_automne_20'],
    'hiver 2021'     : ['2020-12-01', '2021-02-28', 'df_hiver_21'],
    'printemps 2021' : ['2021-03-01', '2021-05-31', 'df_printemps_21'],
    'été 2021'       : ['2021-06-01', '2021-08-31', 'df_été_21'],
    'automne 2021'   : ['2021-09-01', '2021-11-30', 'df_automne_21'],
    'hiver 2022'     : ['2021-12-01', '2022-02-28', 'df_hiver_22'],
    'printemps 2022' : ['2022-03-01', '2022-05-31', 'df_printemps_22'],
    'été 2022'       : ['2022-06-01', '2022-08-31', 'df_été_22'],
    'automne 2022'   : ['2022-09-01', '2022-11-30', 'df_automne_22'],
}
    
# for cle, valeur in dico_saison.items():
#     start_date = pd.to_datetime(valeur[0])
#     end_date = pd.to_datetime(valeur[1])
#     valeur[2] = df1[(df1['date'] >= start_date) & (df1['date'] <= end_date)]
#     print(f"la mediane de la siason {cle} est {valeur[2].groupby('date')['gare'].count().median()}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 5
#       2 df1 = df1.rename(columns={'fields.date': 'date', 'fields.gc_obo_gare_origine_r_name': 'gare', 'fields.gc_obo_type_c': 'type_objet'})
#       4 # retirer les colonnes inutiles
# ----> 5 df1 = df1.drop('type_objet', axis=1)
#       7 # Conversion de la colonne 'fields.date' en type 'datetime'
#       8 df1['date'] = pd.to_datetime(df1['date'])
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
dico_saison = {
    'hiver 2019'     : ['2019-01-01', '2019-02-28', 'df_hiver_19'],
    'printemps 2019' : ['2019-03-01', '2019-05-31', 'df_printemps_19'],
    'été 2019'       : ['2019-06-01', '2019-08-31', 'df_été_19'],
    'automne 2019'   : ['2019-09-01', '2019-11-30', 'df_automne_19'],
    'hiver 2020'     : ['2019-12-01', '2020-02-29', 'df_hiver_20'],
    'printemps 2020' : ['2020-03-01', '2020-05-31', 'df_printemps_20'],
    'été 2020'       : ['2020-06-01', '2020-08-31', 'df_été_20'],
    'automne 2020'   : ['2020-09-01', '2020-11-30', 'df_automne_20'],
    'hiver 2021'     : ['2020-12-01', '2021-02-28', 'df_hiver_21'],
    'printemps 2021' : ['2021-03-01', '2021-05-31', 'df_printemps_21'],
    'été 2021'       : ['2021-06-01', '2021-08-31', 'df_été_21'],
    'automne 2021'   : ['2021-09-01', '2021-11-30', 'df_automne_21'],
    'hiver 2022'     : ['2021-12-01', '2022-02-28', 'df_hiver_22'],
    'printemps 2022' : ['2022-03-01', '2022-05-31', 'df_printemps_22'],
    'été 2022'       : ['2022-06-01', '2022-08-31', 'df_été_22'],
    'automne 2022'   : ['2022-09-01', '2022-11-30', 'df_automne_22'],
    'hiver 2023'     : ['2022-12-01', '2022-12-31']
}
for cle in dico_saison.keys():
    print(cle.split()[1])
# Out:
# 2019
# 2019
# 2019
# 2019
# 2020
# 2020
# 2020
# 2020
# 2021
# 2021
# 2021
# 2021
# 2022
# 2022
# 2022
# 2022
# 2023

# %%
did = 'ah dar'
did.split()[0]
# Out:
# 'ah'

# %%
df1 = pd.read_csv('objets-trouves.csv')
df1 = df1.rename(columns={'fields.date': 'date', 'fields.gc_obo_gare_origine_r_name': 'gare', 'fields.gc_obo_type_c': 'type_objet'})
# retirer les colonnes inutiles
df1 = df1.drop('type_objet', axis=1)
# Conversion de la colonne 'fields.date' en type 'datetime'
df1['date'] = pd.to_datetime(df1['date'])

# %%
def f(x):
    for cle, valeur in dico_saison.items():
        start_date = pd.to_datetime(valeur[0])
        end_date = pd.to_datetime(valeur[1])
        if start_date <= x <= end_date:
            return cle
    return None

date = pd.to_datetime('2020-01-02')
saison = f(date)
print(saison)

df1['saison'] = df1['date'].apply(f)
# Out:
# hiver 2020

# %%
df1.loc[df1['saison'].isna()]
# Out:
# Empty DataFrame
# Columns: [date, gare, saison]
# Index: []

# %%
df1.groupby(['saison','date']).count().reset_index()['gare']
# Out:
# 0         3
# 1        98
# 2       113
# 3       109
# 4       118
#        ...
# 1423     49
# 1424     23
# 1425     86
# 1426     82
# 1427     72
# Name: gare, Length: 1428, dtype: int64

# %%
df1.to_csv('objets-trouves-saison.csv')
